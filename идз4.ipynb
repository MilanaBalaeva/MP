# %% [markdown]
# # Индивидуальное домашнее задание №4

# %% [markdown]
# Выполнил: Дерюгин Дмитрий. Группа 9382. Вариант 5

# %% [markdown]
# ### 1. Построить графически зависимость переменных $Y_i$ от уровней фактора X
#
# x<-c(0, 3, 1, 1, 3, 0, 2, 4, 1, 3, 4, 3, 1, 2, 3, 3, 0, 4, 1, 2, 0, 1, 2, 4, 3, 3, 4, 4, 1, 4, 2, 1, 1, 4, 3, 0, 4, 0, 3, 0, 0, 1, 0, 4, 1, 4, 4, 3, 3, 4)
#
# y<- c(0.81, 12.74, 0.45, 13.61, 16.53, 3.16, 11.74, 25.73, 5.6, 22.37, 10.97, 6.3, 1.5, 12.66, 7.38, 6.37, 1.46, 1.67, 22.02, 8.21, 0.21, 3.09, 6.79, 9.97, 8.2, 20.36, 22.02, 0.84, 17.75, 13.85, 26.8, 10.95, 10.64, 15.9, 28.8, 5.4, 6.19, 6.72, 12.68, 14.94, 1.22, 8.72, 2.47, 22.42, 31.57, 17.91, 0.05, 4.16, 18.53, 5.03)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 2. Сформулировать модели однофакторного дисперсионного анализа зависимости значений Y от уровня фактора X в центральной параметризации. Является ли дизайн данного эксперимента сбалансированнвым? Построить МНК оценки параметров и несмещенную оценку дисперсии. В предположении нормальности ошибок построить доверительные интервалы для параметров уровня доверия $1 - \alpha$

# %% [markdown]
# Модель: $y_{ij}=\mu + \alpha_i^{A} + \epsilon_{ij}$, где $\mu$ - базовое среднее значение, $\alpha_i^{A}$ - главные эффекты фактора A

# %% [markdown]
# Дизайн эксперимента не сбалансирован, так как количество наблюдений в каждой группе отличаются
#
# Построение МНК оценки
#
# $\hat{\beta_i} = \cfrac{1}{n_i}\sum_{j = 1}^{n_i}y_{i, j}$
#
# ![image-2.png](attachment:image-2.png)
#
# $\beta_0 = 4.043333$
#
# $\beta_1 = 11.445455$
#
# $\beta_2 = 13.24$
#
# $\beta_3 = 13.701667$
#
# $\beta_4 = 11.734615$

# %% [markdown]
# Несмещеная оценка дисперсии
#
#
# ![image.png](attachment:image.png)
#
# $\sigma^2 = 63.99469$

# %% [markdown]
# Построение доверительных интервалов
#
# $\hat{\beta_{i}} \sim N(\beta_i, \cfrac{\sigma^2}{n_i})$
#
# $x_{\alpha}: S_{n_i-1}(x_\alpha) = 1 - \cfrac{\alpha}{2}$
#
# $\hat{\beta_i} - \cfrac{x_{\alpha} S}{\sqrt{n_i}} \leq \beta_i \leq \hat{\beta_i} + \cfrac{x_{\alpha} S}{\sqrt{n_i}}$

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
#
# Получаем следующие доверительные интервалы:
#
# $\beta_0 - [-47.41; 55.5]$
#
# $\beta_1 - [-35.09; 57.99]$
#
# $\beta_2 - [-55.79; 82.27]$
#
# $\beta_3 - [-30.86; 58.26]$
#
# $\beta_4 - [-31.08; 54.55]$

# %% [markdown]
# ### 3. Сформулировать модель однофакторного дисперсионного анализа когда наибольший уровень фактора X рассматривается как базовый. Построить МНК оценки параметров и несмещенную оценку дисперсии. В предположении нормальности ошибок построить доверительные интервалы для параметров уровня довери $1 - \alpha $

# %% [markdown]
# $\mu = \sum_{i = 1}^d v_i \beta_i$ - среднее взвешенное
#
# При этом $ v_4 = 1$, тогда при условии$\sum_{i=1}^d v_i = 1$
#
# $\mu = \beta_4$
#
# $\beta_i = \beta_4 + \alpha_i$

# %% [markdown]
# МНК-оценки:
# ![image.png](attachment:image.png)

# %% [markdown]
# $\alpha_0 = -7.6912821$
#
# $\alpha_1 = -0.2891608$
#
# $\alpha_2 =  1.5053846$
#
# $\alpha_3 =  1.9670513$
#
# $\alpha_4 = 0$

# %% [markdown]
# Несмещеная оценка дисперсии
# ![image.png](attachment:image.png)
# $\sigma^2 = 216.996$

# %% [markdown]
# $\hat\alpha_i - \hat\mu-x_{\alpha}s_p \sqrt{\frac{n_i-n_5}{n_in_5}}\leq \alpha_i-\mu_4\leq \hat\alpha_i - \hat\mu+x_{\alpha}s_p \sqrt{\frac{n_i-n_5}{n_in_5}} $
#
# Получаем следующие доверительные интервалы:
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### 4. На основании результатов, полученных в предыдущих пунктах проверить визуально монотонность влияния величины фактора X на результат. Построить графически оценку зависимости уровней фактора X на результат. Как данная зависимость согласуется с результатами пункта 1, если наложить один график на другой

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 5. Провести анализ ошибок. На базе ошибок построить гистограмму с шагом h. Оценить расстояние полученной оценки до класса центрированных нормальных распределений по Колмогорову

# %% [markdown]
# Построение гистограммы с шагом 2.9
# ![image-2.png](attachment:image-2.png)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-4.png](attachment:image-4.png)
# Расстояние равно 0.138391

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 6. Составить таблицу дисперсионного анализа. Проверить значимость влияния фактора X на результаты эксперимента

# %% [markdown]
# $H_0: \beta_0 = \beta_1 =\beta_2 = \beta_3 = \beta_4$
# ![image.png](attachment:image.png)
# Гипотеза H0 опровергается
