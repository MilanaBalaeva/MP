# %% [markdown]
# # Индивидуальное домашнее задание №3

# %% [markdown]
# Выполнил: Дерюгин Дмитрий. Группа 9382. Вариант 5

# %% [markdown]
# ## 1. Построить графически результаты эксперимента. Сформулировать линейную регрессионную модель переменной Y по переменной X. Построить МНК оценки параметров сдвига  𝛽0  и масштаба  𝛽1 . Построить полученную линию регрессии. Оценить визуально соответствие полученных данных и построенной оценки
# X<-c(6, 4, 6, 6, 4, 6, 3, 5, 4, 3, 7, 7, 5, 6, 5, 3, 6, 3, 4, 5, 5, 5, 6, 5, 5, 3, 6, 4, 7, 7, 6, 5, 5, 4,5, 4, 6, 1, 3, 5, 7, 9, 5, 5, 4, 4, 5, 5, 7, 2)
#
# Y: (5.63, 13.43, 15.79, 11.98, 2.15, 12.27, 12.16, 16.17, 28.07, 17.86, 9.01, 17.69, 11.23, 17.57, 19.49, 1.74, 16.8, 4.66, 12.29, 11.47, 15.15, 18.8, 12.22, 8.71, 1.68, 4.45, 6.5, 4.41, 14.42, 11.85, 6.42, 19.59, 9.6, 9.42, 11.24, 19.63, 4.19, 7.64, 5.56, 17.45, 18.79, 22.75, 12.22, 8.69, 10.86, 8.12, 7.16, 22.38, 13.81, 19.53)

# %% [markdown]
# Построение результата эксперимента:
# ![image-3.png](attachment:image-3.png)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Линейная регрессивная модель:
# $Y = \beta_0 + \beta_1 X + \epsilon$
#
# Построение МНК-оценки:
#
# $\beta = (XX^T)^{-1}XY$
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# Получаем:
#
# $\beta_0 = 7.363017$
#
# $\beta_1 = 0.9780208$

# %% [markdown]
# ### 2. Построить и интепретировать несмещенную оценку дисперсии. На базе ошибок построить гистограмму с шагом h. Проверить гипотезу нормальности ошибок на уровне  𝛼  по  𝜒2 . Оценить расстояние полученной оценки до класса нормальных распределений по Колмогорову. Визуально оценить данный факт.

# %% [markdown]
# Общая формула для несмещенной оценки дисперсииЖ
#
# $ \sigma^2 = \cfrac{1}{n - r} \sum_{i=0}^{n}(y_i - \sum_{j=1}^m x_{ij}\beta_j)^2$
#
# В нашем случае:
#
# $ \sigma^2 = \cfrac{1}{n - r} \sum_{i=0}^{n}(y_i - \beta_0 - x_i * \beta_1)^2$
# ![image-2.png](attachment:image-2.png)
#
# Построение гистограммы на базе ошибок:
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# Проверим гипотезу нормальности ошибок на уровне значимости $\alpha_1=0.02$
#
# ![image-7.png](attachment:image-7.png)
# ![image-8.png](attachment:image-8.png)
#
# ![image-11.png](attachment:image-11.png)
# Так как статистика критерия(0.7969684) меньше, чем значение критической области(11.34487), то гипотезу
# принимаем.

# %% [markdown]
# Оценивание расстояния полученной оценки до класса нормальных распределений по Колмогорову
#
# $D=sup|F_n(x)-F(x)|$, где $F_n(x)$ - эмпирическая ф.р; $F(x)$-ф.р
#
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ### 3. В предположении нормальности ошибок построить доверительные интервалы для параметров  𝛽0  и  𝛽1  уровня доверия  1−𝛼 . Построить доверительный эллипс уровня доверия  1−𝛼  для  (𝛽0,𝛽1) (вычислить его полуоси)

# %% [markdown]
# Доверительный интервал:
#
# $[{\beta_i} - t_{1 - \alpha/2, N-2}B\sqrt(\sigma^2), {\beta_i} + t_{1 - \alpha/2, N-2}B\sqrt(\sigma^2)]$, где $B=C^T(XX^T)C$
#
# ![image.png](attachment:image.png)
#
# Получаем:
#
# $\beta_0 - [0.26125;14.46478]$
#
# $\beta_1 - [2.3508708;-0.398293]$
#
# Построение доверительного эллипсиса
#
# ![image-2.png](attachment:image-2.png)
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# ### 4. Сформулировать гипотезу независимости переменной Y от переменной X. Провести проверку значимости

# %% [markdown]
#  \begin{cases}
#    H_0: \beta_1 = 0\\
#    H_1: \beta_1 \neq 0
# \end{cases}
# F-критерий:
#
# $F = \frac{(C^T(XX^T)^{-1}XY)^TB^{-1}C^T(XX^T)^{-1}XY}{q\sigma^2}$
# ![image.png](attachment:image.png)

# %% [markdown]
# Получаем:
#
# F-статистика: 4.582468
#
# p-значение: 0.03740845
#
# p-значение больше $\alpha$. Значит гипотезу принимаем

# %% [markdown]
# ### 5. Сформулировать модель, включающую дополнительный член с $X^2$. Построить МНК оценки параметров $\beta_1, \beta_2, \beta_3$ в данной модели. Изобразить графически полученную регрессионную зависимость

# %% [markdown]
# Модель:
#
# $Y = \beta_1 + \beta_2 X + \beta_3 X^2 + \epsilon$
# ![image-3.png](attachment:image-3.png)
# ![image-2.png](attachment:image-2.png)
#
# Оценки
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ### 6. Построить несмещенную оценку дисперсии. Провести исследование нормальности ошибок как в п.2

# %% [markdown]
# Общая формула для несмещенной оценки дисперсииЖ
#
# $ \sigma^2 = \cfrac{1}{n - r} \sum_{i=0}^{n}(y_i - \sum_{j=1}^m x_{ij}\beta_j)^2$
#
# В нашем случае:
#
# $ \sigma^2 = \cfrac{1}{n - r} \sum_{i=0}^{n}(y_i - \beta_0 - x_i * \beta_1 - x^2_i * \beta_2)^2$
# ![image.png](attachment:image.png)
#
# Построение гистограммы на базе ошибок:
# ![image-5.png](attachment:image-5.png)
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# Проверим гипотезу нормальности ошибок на уровне значимости $\alpha_1=0.02$
#
#
# ![image-5.png](attachment:image-5.png)
# ![image-4.png](attachment:image-4.png)
#
# ![image-6.png](attachment:image-6.png)
# Так как статистика критерия(1.223388) меньше, чем значение критической области(9.21034), то гипотезу
# принимаем.

# %% [markdown]
# Оценивание расстояния полученной оценки до класса нормальных распределений по Колмогорову
#
# $D=sup|F_n(x)-F(x)|$, где $F_n(x)$ - эмпирическая ф.р; $F(x)$-ф.р
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 7. В предположении нормальности ошибок построить доверительные интервалы для параметров $\beta_1, \beta_2, \beta_3$ в данной модели. Написать уравнение эллипсоида уровня $1 - \alpha$

# %% [markdown]
# Доверительный интервал:
#
# $[{\beta_i} - t_{1 - \alpha/2, N-2}B\sqrt(\sigma^2), {\beta_i} + t_{1 - \alpha/2, N-2}B\sqrt(\sigma^2)]$, где $B=C^T(XX^T)C$
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
# Получаем:
#
# $\beta_0 - [-3.366026;26.565578]$
#
# $\beta_1 - [-6.982922;5.137713]$
#
# $\beta_2 - [-0.4082591;0.7961769]$

# %% [markdown]
# ### 8. Сформулировать гипотезу линейной регрессионной зависимости переменной Y от переменной X и проверить ее значимость на уровне $\alpha$

# %% [markdown]
# \begin{cases}
#    H_0: \beta_3 = 0\\
#    H_1: \beta_3 \neq 0
# \end{cases}
# F-критерий:
#
# $F = \frac{(C^T(XX^T)^{-1}XY)^TB^{-1}C^T(XX^T)^{-1}XY}{q\sigma^2}$
# ![image.png](attachment:image.png)
#
# Получаем:
#
# F-статистика: 3.029626
#
# p-значение: 0.08830085
#
# p-значение больше $\alpha$. Значит гипотезу принимаем
